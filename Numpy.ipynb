# %%
import pandas as pd
import numpy as np

# %%
city_cc= pd.read_excel('C:\\Users\\Dreamuser\\Desktop\\Numpy Class\\Dataset\\cc.xlsx')
city_cc
# Out:
#             city       latd       longd  elevation_m  elevation_ft  \
# 0       Adelanto  34.576111 -117.432778        875.0        2871.0
# 1    AgouraHills  34.153333 -118.761667        281.0         922.0
# 2        Alameda  37.756111 -122.274444          NaN          33.0
# 3         Albany  37.886944 -122.297778          NaN          43.0
# 4       Alhambra  34.081944 -118.135000        150.0         492.0
# ..           ...        ...         ...          ...           ...
# 477   Yountville  38.403056 -122.362222         30.0          98.0
# 478        Yreka  41.726667 -122.637500        787.0        2582.0
# 479     YubaCity  39.134722 -121.626111         18.0          59.0
# 480      Yucaipa  34.030278 -117.048611        798.0        2618.0
# 481  YuccaValley  34.133333 -116.416667       1027.0        3369.0
#
#      population_total  area_total_sq_mi  area_land_sq_mi  area_water_sq_mi
# 0               31765            56.027           56.009             0.018
# ...

# %%
latitude=np.array(city_cc["latd"])
longtitude= np.array(city_cc["longd"])
city=np.array(city_cc["city"])

print("latitude:",latitude, "\n")
print("longtitude:", longtitude, '\n')
print("city:", city)
# Out:
# latitude: [34.57611111 34.15333333 37.75611111 37.88694444 34.08194444 33.575
#  41.48722222 38.41944444 38.16805556 33.83611111 40.45222222 38.06833333
#  38.005      34.51666667 34.13277778 40.86638889 35.12083333 33.86722222
#  35.20916667 35.48416667 37.45861111 37.34777778 38.89861111 33.34083333
#  36.00416667 34.13055556 35.36666667 34.08277778 33.93166667 34.9
#  33.92416667 33.98333333 33.88805556 33.96805556 37.51805556 37.87277778
#  38.06333333 37.87166667 34.07305556 34.24138889 39.41388889 37.3635
#  40.88277778 33.61027778 34.14944444 32.97861111 33.92333333 37.93194444
#  37.68083333 34.61416667 33.85611111 34.18027778 37.58333333 34.13833333
#  32.67888889 35.12583333 33.98805556 33.12555556 38.58138889 34.23333333
#  37.28388889 33.68416667 36.97638889 33.12194444 36.55527778 34.39916667
#  33.83972222 33.80777778 37.60138889 33.86833333 39.74       34.01777778
#  33.97527778 37.11666667 32.62777778 38.7        34.11       37.94111111
# ...

# %%
# sum of latitude
print("Total Latd;", np.sum(latitude), "\n")
print("Total longd;", np.sum(longtitude), "\n")
print("latd_mean;", np.mean(latitude),"\n")
print("latd_mean;", np.mean(longtitude))
# Out:
# Total Latd; 17397.83245536
#
# Total longd; -57761.778112
#
# latd_mean; 36.09508808165975
#
# latd_mean; -119.8377139253112

# %%
# city with the maximum latitude
city[latitude.argmax()]
# Out:
# 'Dorris'

# %%
# city with the minimum latitude
city[latitude.argmin()]
# Out:
# 'ImperialBeach'

# %%
# city with the maximum longtitude
city[longtitude.argmax()]
# Out:
# 'Blythe'

# %%
# city with the minimum longtitude
city[longtitude.argmin()]
# Out:
# 'Ferndale'

# %%
area_total_sq_mi=np.array(city_cc["area_total_sq_mi"])
area_land_sq_mi=np.array(city_cc['area_land_sq_mi'])
area_water_sq_mi=np.array(city_cc['area_water_sq_mi'])
print(area_total_sq_mi)
print(area_land_sq_mi)
print(area_water_sq_mi)
# Out:
# [5.60270e+01 7.82200e+00 2.29600e+01 5.46500e+00 7.63200e+00 7.47200e+00
#  2.44900e+00 3.14000e-01 4.84500e+00 5.08110e+01 6.62000e+00 3.63700e+00
#  2.90830e+01 7.35230e+01 1.11330e+01 1.09940e+01 5.83500e+00 1.62100e+00
#  4.81900e+00 2.61300e+01 5.04900e+00 6.09600e+00 7.16600e+00 2.93700e+00
#  1.94220e+01 9.66900e+00 1.43609e+02 6.78600e+00 2.30990e+01 4.13940e+01
#  3.09260e+01 2.62000e+00 6.17000e+00 2.46300e+00 4.63000e+00 2.40600e+00
#  1.57200e+01 1.76960e+01 5.71000e+00 6.53400e+00 6.36000e-01 1.91100e+00
#  6.22000e-01 2.69720e+01 1.95800e+00 7.68200e+00 1.21090e+01 1.48050e+01
#  2.00770e+01 1.58300e+00 1.05530e+01 1.73790e+01 6.05700e+00 1.33000e+01
#  8.39100e+00 2.03631e+02 1.48470e+01 3.71600e+00 2.61300e+00 1.95430e+01
#  5.88600e+00 4.67100e+00 1.67600e+00 3.91100e+01 1.08000e+00 9.27200e+00
#  1.89680e+01 2.17560e+01 8.01900e+00 8.85600e+00 3.30950e+01 2.96520e+01
#  4.47490e+01 7.66100e+00 5.20940e+01 1.42280e+01 1.34860e+01 3.83600e+00
# ...

# %%
# total of area_total_sq_mi, area_land_sq_mi, area_water_sq_mi
print("area_total_sq_mi:", np.nansum(area_total_sq_mi))
print('area_land_sq_mi:', np.sum(area_land_sq_mi))
print('area_water_sq_mi;', np.nansum(area_water_sq_mi))
# Out:
# area_total_sq_mi: 8852.248
# area_land_sq_mi: 8117.353000000001
# area_water_sq_mi; 764.612

# %%
# minimum area_total_sq_mi
print('Minimum area_total_sq_mi:', area_total_sq_mi.min())
# Out:
# Minimum area_total_sq_mi: nan

# %%
# maximum of area_total_sq_mi
print('Maximum area_total_sq_mi:', area_total_sq_mi.max())
# Out:
# Maximum area_total_sq_mi: nan

# %%
# minimum of area_land_sq_mi
print('minimum area_land_sq_mi:', area_land_sq_mi.min())
# Out:
# minimum area_land_sq_mi: 0.314

# %%
# mmaximum of area_land_sq_mi
print('maximum area_land_sq_mi:', area_land_sq_mi.max())
# Out:
# maximum area_land_sq_mi: 469.0

# %%
population=np.array(city_cc["population_total"])
print('population:', population)
# Out:
# population: [  31765   20330   75467   18969   83089   47823    2827     185   19454
#   336000    9932    3836  107100   69135   56364   17231   17716   16522
#    19304   28310    6914   28168   13330    3728   13239   46361  347483
#    75390   29603   22639   36877   35477   76616   42072   25835    2068
#    26997  112580   34290    5019    1707    3879    1253   20817    1048
#    24953   39282   51481    4282    4828   80530  103340   28806   23058
#    38572   14120    7879    7705    5155   65201   39349   10561    9918
#   105328    3722   13040   91714   51200   45417   49041   86187   77983
#    75655   18720  243916   83301   34926   10897   15250    8618  101314
#    40704   13380    1963    1792   52154    5971   12823   96455  122067
#    25515   17382  158391   24697    9253  109960    7310   47796    7643
#    23805   38883   58302   47802  101123   33351   42039   65622   53819
#     4161    1624   25938   55544   21453   18351     939    4950  111772
# ...

# %%
# Total Population
print("Total population:", np.sum(population))
# Out:
# Total population: 31279358

# %%
# city with the minimum population
city[population.argmin()]
# Out:
# 'Pomona'

# %%
# city with the maximum population
city[population.argmax()]
# Out:
# 'LosAngeles'

# %%
# maximum population
print('maximum population;', population.max())
# Out:
# maximum population; 3884307

# %%
# minimum population
print('minimum population;', population.min())
# Out:
# minimum population; 1

# %%
# area_total_sq_mi with the maximum population
area_total_sq_mi[population.argmax()]
# Out:
# 503.0

# %%
# area_total_sq_mi with the minimum population
area_total_sq_mi[population.argmin()]
# Out:
# 22.964

# %%
# area_land_sq_mi with the maximum population
area_land_sq_mi[population.argmax()]
# Out:
# 469.0

# %%
# area_land_sq_mi with the minimum population
area_land_sq_mi[population.argmin()]
# Out:
# 22.952

# %%
# area_water_sq_mi with the maximum population 
area_water_sq_mi[population.argmax()]
# Out:
# 34.0

# %%
# area_water_sq_mi with the minimum population 
area_water_sq_mi[population.argmin()]
# Out:
# 0.012

# %% [markdown]
# ### Assignment 2

# %%
city_boy= pd.read_csv('C:\\Users\\Dreamuser\\Desktop\\Numpy Class\\Dataset\\product.csv')
city_boy
# Out:
#                ID  Year_of_Birth Education_Level Marital_Status  \
# 0     ID_4A9AR6FQ           1955      Graduation       Divorced
# 1     ID_X28T3VEK           1958      Graduation       Together
# 2     ID_AWXARH57           1962      Graduation         Single
# 3     ID_FQVZHE81           1979        2n Cycle         Single
# 4     ID_QVLWGPRN           1959      Graduation        Married
# ...           ...            ...             ...            ...
# 1563  ID_XWINUFGG           1970      Graduation        Married
# 1564  ID_GLVIHZLR           1980      Graduation         Single
# 1565  ID_O11VSIJY           1952          Master        Married
# 1566  ID_VS37P6MS           1964             PhD         Single
# 1567  ID_AKHOY7EI           1970      Graduation       Together
#
#       Disposable_Income  No_of_Kids_in_home  No_of_Teen_in_home Date_Customer  \
# 0               77504.4                   1                   1    22-06-2014
# ...

# %%
use product data to compute the following using np: 
extract the  Year_of_Birth, Education_Level, Marital_Status, Disposable_Income, No_of_Kids_in_home and       
No_of_Teen_in_home column from the data
    compute the aggregation of sum of Amount_on_Wines, Amount_on_Fruits, Amount_on_MeatProducts, Amount_on_FishProducts,
    Amount_on_SweetProducts,Amount_on_GoldProds, mean and median
    compute the maximum  and minimum of Amount_on_Wines, Amount_on_Fruits, Amount_on_MeatProducts, Amount_on_FishProducts, 
    Amount_on_SweetProducts,Amount_on_GoldProds  
    indicate the Education_Level and Marital_Status with maximum and minimum Amount_on_Wines, Amount_on_Fruits, Amount_on_MeatProducts, Amount_on_FishProducts, 
    Amount_on_SweetProducts,Amount_on_GoldProds
    indicate the Year_of_Birth with minimum and maximum Amount_on_Wines, Amount_on_Fruits, Amount_on_MeatProducts, Amount_on_FishProducts, 
    Amount_on_SweetProducts,Amount_on_GoldProds
# Out:
#   File "<ipython-input-81-136225c3a6fb>", line 1
#     use product data to compute the following using np:
#         ^
# SyntaxError: invalid syntax

# %%
YOB = np.array(city_boy['Year_of_Birth'])
EDU_LEVEL = np.array(city_boy['Education_Level'])
MARITAL = np.array(city_boy['Marital_Status'])
DISPOSABLE = np.array(city_boy['Disposable_Income'])
NKH =np.array(city_boy['No_of_Kids_in_home'])
NTH = np.array(city_boy['No_of_Teen_in_home'])
WINES = np.array(city_boy['Amount_on_Wines'])
FRUITS = np.array(city_boy['Amount_on_Fruits'])
MEATPRODUCTS = np.array(city_boy['Amount_on_MeatProducts'])
FISHPRODUCTS= np.array(city_boy['Amount_on_FishProducts'])
SWEETPRODUCTS = np.array(city_boy['Amount_on_SweetProducts'])
GOLDPRODS =np.array(city_boy['Amount_on_GoldProds'])


print("Year of birth:", YOB, "\n")
print("Education Level:", EDU_LEVEL, "\n")
print("Marital Status:", MARITAL, "\n")
print("Disposable Income:", DISPOSABLE, "\n")
print("No_of_Kids_in_home:", NKH , "\n")
print("No_of_Teen_in_home:", NTH, "\n")
print("Amount_on_Wines:", WINES, "\n")
print("Amount_on_Fruits:",FRUITS, "\n")
print("Amount_on_FishProducts:", FISHPRODUCTS, '\n')
print("Amount_on_SweetProducts:",SWEETPRODUCTS, "\n")
print("Amount_on_MeatProducts:",MEATPRODUCTS, "\n")
print("Amount_on_GoldProds:", GOLDPRODS)
# Out:
# Year of birth: [1955 1958 1962 ... 1952 1964 1970]
#
# Education Level: ['Graduation' 'Graduation' 'Graduation' ... 'Master' 'PhD' 'Graduation']
#
# Marital Status: ['Divorced' 'Together' 'Single' ... 'Married' 'Single' 'Together']
#
# Disposable Income: [ 77504.4  56784.  103714.8 ...  80857.2  58701.6  27873.6]
#
# No_of_Kids_in_home: [1 0 0 ... 0 1 1]
#
# No_of_Teen_in_home: [1 1 0 ... 1 1 0]
#
# Amount_on_Wines: [ 71 205 469 ... 820  57  18]
#
# Amount_on_Fruits: [ 3 22 31 ... 11  3  5]
#
# Amount_on_FishProducts: [ 0 50 29 ... 11  0  6]
#
# Amount_on_SweetProducts: [ 6 15 18 ...  0  0  1]
#
# Amount_on_MeatProducts: [ 16 111 873 ...  53   9  18]
#
# Amount_on_GoldProds: [20 19 37 ... 70  1  0]

# %%
# sum of Amount_on_Wines, Amount_on_Fruits, Amount_on_MeatProducts, Amount_on_FishProducts, Amount_on_SweetProducts,Amount_on_GoldProds
print("Amount_on_Wines:", np.sum(WINES), "\n")
print("Amount_on_Fruits:", np.sum(FRUITS), '\n')
print("Amount_on_Sweet:", np.sum(SWEETPRODUCTS), '\n')
print("Amount_on_MeatProducts:", np.sum(MEATPRODUCTS), '\n')
print("Amount_on_GoldProds:", np.sum(GOLDPRODS), '\n')
print("Amount_on_FishProducts:", np.sum(FISHPRODUCTS))
# Out:
# Amount_on_Wines: 475402
#
# Amount_on_Fruits: 45615
#
# Amount_on_Sweet: 42023
#
# Amount_on_MeatProducts: 264014
#
# Amount_on_GoldProds: 68583
#
# Amount_on_FishProducts: 58277

# %%
#  mean of Amount_on_Wines, Amount_on_Fruits, Amount_on_MeatProducts, Amount_on_FishProducts, Amount_on_SweetProducts,Amount_on_GoldProds
print("Mean of Amount_on_Wines:", np.mean(WINES), "\n")
print("Mean of Amount_on_Fruits:", np.mean(FRUITS), '\n')
print("Mean of Amount_on_Sweet:", np.mean(SWEETPRODUCTS), '\n')
print("Mean of Amount_on_MeatProducts:", np.mean(MEATPRODUCTS), '\n')
print("Mean of Amount_on_GoldProds:", np.mean(GOLDPRODS), '\n')
print("Mean of Amount_on_FishProducts:", np.mean(FISHPRODUCTS))
# Out:
# Mean of Amount_on_Wines: 303.1900510204082
#
# Mean of Amount_on_Fruits: 29.091198979591837
#
# Mean of Amount_on_Sweet: 26.800382653061224
#
# Mean of Amount_on_MeatProducts: 168.3762755102041
#
# Mean of Amount_on_GoldProds: 43.73915816326531
#
# Mean of Amount_on_FishProducts: 37.16645408163265

# %%
# median of Amount_on_Wines, Amount_on_Fruits, Amount_on_MeatProducts, Amount_on_FishProducts, Amount_on_SweetProducts,Amount_on_GoldProds
print("Median of Amount_on_Wines:", np.median(WINES), "\n")
print("Medianof Amount_on_Fruits:", np.median(FRUITS), '\n')
print("Median of Amount_on_Sweet:", np.median(SWEETPRODUCTS), '\n')
print("Median of Amount_on_MeatProducts:", np.median(MEATPRODUCTS), '\n')
print("Median of Amount_on_GoldProds:", np.median(GOLDPRODS), '\n')
print("Median of Amount_on_FishProducts:", np.median(FISHPRODUCTS))
# Out:
# Median of Amount_on_Wines: 167.0
#
# Medianof Amount_on_Fruits: 11.0
#
# Median of Amount_on_Sweet: 8.0
#
# Median of Amount_on_MeatProducts: 64.0
#
# Median of Amount_on_GoldProds: 25.0
#
# Median of Amount_on_FishProducts: 12.0

# %%
#  minimum of Amount_on_Wines, Amount_on_Fruits, Amount_on_MeatProducts, Amount_on_FishProducts, Amount_on_SweetProducts,Amount_on_GoldProds
print("Minimum of Amount_on_Wines:", WINES.min(), "\n")
print("Minimum of Amount_on_Fruits:",FRUITS.min(), "\n")
print("Minimum of Amount_on_FishProducts:", FISHPRODUCTS.min(), '\n')
print("Minimum of Amount_on_SweetProducts:",SWEETPRODUCTS.min(), "\n")
print("Minimum of Amount_on_MeatProducts:",MEATPRODUCTS.min(), "\n")
print("Minimum of Amount_on_GoldProds:", GOLDPRODS.min())
# Out:
# Minimum of Amount_on_Wines: 5
#
# Minimum of Amount_on_Fruits: 3
#
# Minimum of Amount_on_FishProducts: 0
#
# Minimum of Amount_on_SweetProducts: 0
#
# Minimum of Amount_on_MeatProducts: 0
#
# Minimum of Amount_on_GoldProds: 0

# %%
#  maximum of Amount_on_Wines, Amount_on_Fruits, Amount_on_MeatProducts, Amount_on_FishProducts, Amount_on_SweetProducts,Amount_on_GoldProds
print("Maximum of Amount_on_Wines:", WINES.max(), "\n")
print("Maximum of Amount_on_Fruits:",FRUITS.max(), "\n")
print("Maximum of Amount_on_FishProducts:", FISHPRODUCTS.max(), '\n')
print("Maximum of Amount_on_SweetProducts:",SWEETPRODUCTS.max(), "\n")
print("Maximum of Amount_on_MeatProducts:",MEATPRODUCTS.max(), "\n")
print("Maximum of Amount_on_GoldProds:", GOLDPRODS.max())
# Out:
# Maximum of Amount_on_Wines: 1498
#
# Maximum of Amount_on_Fruits: 202
#
# Maximum of Amount_on_FishProducts: 259
#
# Maximum of Amount_on_SweetProducts: 263
#
# Maximum of Amount_on_MeatProducts: 1725
#
# Maximum of Amount_on_GoldProds: 362

# %%
#  Educational level maximum  Amount_on_Wines, Amount_on_Fruits, Amount_on_MeatProducts, Amount_on_FishProducts,Amount_on_SweetProducts,Amount_on_GoldProds
argmax_wines= EDU_LEVEL[WINES.argmax()]
argmax_fruits=EDU_LEVEL[FRUITS.argmax()]
argmax_meat=EDU_LEVEL[MEATPRODUCTS.argmax()]
argmax_fish=EDU_LEVEL[FISHPRODUCTS.argmax()]
argmax_sweet= EDU_LEVEL[SWEETPRODUCTS.argmax()]
argmax_gold= EDU_LEVEL[GOLDPRODS.argmax()]
print("Educationa level with the maximum number of Wines:", argmax_wines, "\n")
print("Educationa level with the maximum number of Fruits:", argmax_fruits, "\n")
print("Educationa level with the maximum number of MeatProducts:", argmax_meat, "\n")
print("Educationa level with the maximum number of FishProducts:", argmax_fish, "\n")
print("Educationa level with the maximum number of SweetProducts:", argmax_sweet, "\n")
print("Educationa level with the maximum number of GoldProds:", argmax_gold)
# Out:
# Educationa level with the maximum number of Wines: PhD
#
# Educationa level with the maximum number of Fruits: Graduation
#
# Educationa level with the maximum number of MeatProducts: Graduation
#
# Educationa level with the maximum number of FishProducts: 2n Cycle
#
# Educationa level with the maximum number of SweetProducts: Graduation
#
# Educationa level with the maximum number of GoldProds: Graduation

# %%
#  Educational level mimimun  Amount_on_Wines, Amount_on_Fruits, Amount_on_MeatProducts, Amount_on_FishProducts,Amount_on_SweetProducts,Amount_on_GoldProds
argmin_wines= EDU_LEVEL[WINES.argmin()]
argmin_fruits=EDU_LEVEL[FRUITS.argmin()]
argmin_meat=EDU_LEVEL[MEATPRODUCTS.argmin()]
argmin_fish=EDU_LEVEL[FISHPRODUCTS.argmin()]
argmin_sweet= EDU_LEVEL[SWEETPRODUCTS.argmin()]
argmin_gold= EDU_LEVEL[GOLDPRODS.argmin()]
print("Educationa level with the miniimum number of Wines:", argmin_wines, "\n")
print("Educationa level with the minimum number of Fruits:", argmin_fruits, "\n")
print("Educationa level with the minimum number of MeatProducts:", argmin_meat, "\n")
print("Educationa level with the minimum number of FishProducts:", argmin_fish, "\n")
print("Educationa level with the minimum number of SweetProducts:", argmin_sweet, "\n")
print("Educationa level with the minimum number of GoldProds:", argmin_gold)
# Out:
# Educationa level with the miniimum number of Wines: Basic
#
# Educationa level with the minimum number of Fruits: Graduation
#
# Educationa level with the minimum number of MeatProducts: 2n Cycle
#
# Educationa level with the minimum number of FishProducts: Graduation
#
# Educationa level with the minimum number of SweetProducts: Master
#
# Educationa level with the minimum number of GoldProds: Graduation

# %%
#  Marital Status maximum  Amount_on_Wines, Amount_on_Fruits, Amount_on_MeatProducts, Amount_on_FishProducts,Amount_on_SweetProducts,Amount_on_GoldProds
argmax_wines= MARITAL[WINES.argmax()]
argmax_fruits=MARITAL[FRUITS.argmax()]
argmax_meat=MARITAL[MEATPRODUCTS.argmax()]
argmax_fish=MARITAL[FISHPRODUCTS.argmax()]
argmax_sweet= MARITAL[SWEETPRODUCTS.argmax()]
argmax_gold= MARITAL[GOLDPRODS.argmax()]
print("Marital Status with the maximum number of Wines:", argmax_wines, "\n")
print("Marital Status with the maximum number of Fruits:", argmax_fruits, "\n")
print("Marital Status with the maximum number of MeatProducts:", argmax_meat, "\n")
print("Marital Status with the maximum number of FishProducts:", argmax_fish, "\n")
print("Marital Status with the maximum number of SweetProducts:", argmax_sweet, "\n")
print("Marital Status with the maximum number of GoldProds:", argmax_gold)
# Out:
# Marital Status with the maximum number of Wines: Married
#
# Marital Status with the maximum number of Fruits: Single
#
# Marital Status with the maximum number of MeatProducts: Together
#
# Marital Status with the maximum number of FishProducts: Widow
#
# Marital Status with the maximum number of SweetProducts: Single
#
# Marital Status with the maximum number of GoldProds: Single

# %%
#  Marital Status minimum Amount_on_Wines, Amount_on_Fruits, Amount_on_MeatProducts, Amount_on_FishProducts,Amount_on_SweetProducts,Amount_on_GoldProds
argmin_wines= MARITAL[WINES.argmin()]
argmin_fruits=MARITAL[FRUITS.argmin()]
argmin_meat=MARITAL[MEATPRODUCTS.argmin()]
argmin_fish=MARITAL[FISHPRODUCTS.argmin()]
argmin_sweet= MARITAL[SWEETPRODUCTS.argmin()]
argmin_gold= MARITAL[GOLDPRODS.argmin()]
print("Marital Status with the mimimun number of Wines:", argmin_wines, "\n")
print("Marital Status with the mimimun number of Fruits:", argmin_fruits, "\n")
print("Marital Status with the mimimun number of MeatProducts:", argmin_meat, "\n")
print("Marital Status with the mimimun number of FishProducts:", argmin_fish, "\n")
print("Marital Status with the mimimun number of SweetProducts:", argmin_sweet, "\n")
print("Marital Status with the mimimun number of GoldProds:", argmin_gold)
# Out:
# Marital Status with the mimimun number of Wines: Single
#
# Marital Status with the mimimun number of Fruits: Divorced
#
# Marital Status with the mimimun number of MeatProducts: Divorced
#
# Marital Status with the mimimun number of FishProducts: Divorced
#
# Marital Status with the mimimun number of SweetProducts: Married
#
# Marital Status with the mimimun number of GoldProds: Together

# %%
# The Year_of_Birth with the minimum Amount_on_Wines, Amount_on_Fruits, Amount_on_MeatProducts, Amount_on_FishProducts, Amount_on_SweetProducts,Amount_on_GoldProds
argmin_wines= YOB[WINES.argmin()]
argmin_fruits=YOB[FRUITS.argmin()]
argmin_meat=YOB[MEATPRODUCTS.argmin()]
argmin_fish=YOB[FISHPRODUCTS.argmin()]
argmin_sweet= YOB[SWEETPRODUCTS.argmin()]
argmin_gold= YOB[GOLDPRODS.argmin()]
print("Year_of_Birth with the mimimun number of Wines:", argmin_wines, "\n")
print("Year_of_Birth with the mimimun number of Fruits:", argmin_fruits, "\n")
print("Year_of_Birth with the mimimun number of MeatProducts:", argmin_meat, "\n")
print("Year_of_Birth with the mimimun number of FishProducts:", argmin_fish, "\n")
print("Year_of_Birth with the mimimun number of SweetProducts:", argmin_sweet, "\n")
print("Year_of_Birth with the mimimun number of GoldProds:", argmin_gold)
# Out:
# Year_of_Birth with the mimimun number of Wines: 1992
#
# Year_of_Birth with the mimimun number of Fruits: 1955
#
# Year_of_Birth with the mimimun number of MeatProducts: 1976
#
# Year_of_Birth with the mimimun number of FishProducts: 1955
#
# Year_of_Birth with the mimimun number of SweetProducts: 1960
#
# Year_of_Birth with the mimimun number of GoldProds: 1956

# %%
# The Year_of_Birth with the maximum Amount_on_Wines, Amount_on_Fruits, Amount_on_MeatProducts, Amount_on_FishProducts, Amount_on_SweetProducts,Amount_on_GoldProds
argmax_wines= YOB[WINES.argmin()]
argmax_fruits=YOB[FRUITS.argmin()]
argmax_meat=YOB[MEATPRODUCTS.argmin()]
argmax_fish=YOB[FISHPRODUCTS.argmin()]
argmax_sweet= YOB[SWEETPRODUCTS.argmin()]
argmax_gold= YOB[GOLDPRODS.argmin()]
print("Year_of_Birth with the maximum number of Wines:", argmax_wines, "\n")
print("Year_of_Birth with the maximum number of Fruits:", argmax_fruits, "\n")
print("Year_of_Birth with the maximum number of Meatproducts:", argmax_meat, "\n")
print("Year_of_Birth with the maximum number of FishProducts:", argmax_fish, "\n")
print("Year_of_Birth with the maximum number of SweetProducts:", argmax_sweet, "\n")
print("Year_of_Birth with the maximum number of GoldProds:", argmax_gold)
# Out:
# Year_of_Birth with the maximum number of Wines: 1992
#
# Year_of_Birth with the maximum number of Fruits: 1955
#
# Year_of_Birth with the maximum number of Meatproducts: 1976
#
# Year_of_Birth with the maximum number of FishProducts: 1955
#
# Year_of_Birth with the maximum number of SweetProducts: 1960
#
# Year_of_Birth with the maximum number of GoldProds: 1956
